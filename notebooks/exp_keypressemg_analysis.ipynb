# %%
import pandas as pd
from matplotlib import pyplot as plt
from pathlib import Path
import ipywidgets as widgets

# %%
csv_folder = Path('../csv').resolve()
assert csv_folder.exists(), f'csv folder does not exist: {csv_folder}'
csv_files = csv_folder.glob('**/keypress*.csv')
# csv_files = csv_folder.glob('**/emg_*.csv')
csv_files = list(csv_files)
csv_files
# Out:
# [PosixPath('/home/user1/GIT/fed_trainers/csv/keypressemg_gep_public.csv'),
#  PosixPath('/home/user1/GIT/fed_trainers/csv/keypressemg_gep_private.csv'),
#  PosixPath('/home/user1/GIT/fed_trainers/csv/keypressemg_sgd_dp.csv')]

# %%
df_list = [pd.read_csv(f.as_posix()) for f in csv_files]

df = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
df
# Out:
#        data_name  num-steps optimizer     lr  num-client-agg   clip  \
# 0    keypressemg        200       sgd  0.001               5  1.000
# 1    keypressemg        200       sgd  0.001               5  1.000
# 2    keypressemg        200       sgd  0.001               5  1.000
# 3    keypressemg        200       sgd  0.001               5  1.000
# 4    keypressemg        200       sgd  0.010               5  1.000
# ..           ...        ...       ...    ...             ...    ...
# 217  keypressemg        250       sgd  0.001               5  0.100
# 218  keypressemg        250       sgd  0.001               5  0.100
# 219  keypressemg        300       sgd  0.001               5  0.100
# 220  keypressemg        300       sgd  0.001               5  0.010
# 221  keypressemg        300       sgd  0.001               5  0.001
#
#      noise-multiplier  seed  history_size  basis_size   dp_method  \
# 0                 0.1    43            20          19  GEP_PUBLIC
# 1                 0.1    43            20          19  GEP_PUBLIC
# 2                 0.0    43            20          19  GEP_PUBLIC
# 3                 0.0    43            20          19  GEP_PUBLIC
# 4                 0.1    43            20          19  GEP_PUBLIC
# ..                ...   ...           ...         ...         ...
# 217               0.1    42             1           1      SGD_DP
# 218               0.0    42             1           1      SGD_DP
# 219               0.1    42             1           1      SGD_DP
# 220               0.1    42             1           1      SGD_DP
# 221               0.1    42             1           1      SGD_DP
#
#      epoch_of_best_val  best_val_acc  test_avg_acc  reconstruction_similarity
# 0                  189      0.096337      0.096337                   0.097629
# 1                  129      0.090253      0.090253                   0.103773
# 2                  194      0.096616      0.096616                   0.240297
# 3                  129      0.091346      0.091346                   0.256249
# 4                  124      0.099273      0.099273                   0.148422
# ..                 ...           ...           ...                        ...
# 217                 49      0.047260      0.047260                   0.000000
# 218                134      0.045442      0.045442                   0.000000
# 219                299      0.049217      0.049217                   0.000000
# 220                269      0.044603      0.044603                   0.000000
# 221                214      0.043345      0.043345                   0.000000
#
# [222 rows x 15 columns]

# %%
depth_power = 1
df.groupby(['dp_method', 'noise-multiplier'])['test_avg_acc'].median()
# Out:
# dp_method    noise-multiplier
# GEP_PRIVATE  0.0                 0.093580
#              0.1                 0.076505
# GEP_PUBLIC   0.0                 0.091783
#              0.1                 0.090149
# SGD_DP       0.0                 0.100112
#              0.1                 0.070050
# Name: test_avg_acc, dtype: float64

# %%
res = widgets.RadioButtons(
    options=['SGD_DP', 'GEP_PUBLIC', 'GEP_PRIVATE'],
    description='DP method:',
    disabled=False
)


# Display the radio button widget
display(res)
# Out:
# RadioButtons(description='DP method:', options=('SGD_DP', 'GEP_PUBLIC', 'GEP_PRIVATE'), value='SGD_DP')

# %%
good_acc = df[(df['dp_method'] == res.value)]
# good_acc = df[(df['dp_method'] == res.value) & (df['test_avg_acc'] > 0.1)]
good_acc.groupby(['noise-multiplier'])['test_avg_acc'].max()
# Out:
# noise-multiplier
# 0.000     0.607075
# 2.016     0.607075
# 4.720     0.607075
# 12.790    0.607075
# 25.000    0.615040
# Name: test_avg_acc, dtype: float64

# %%
good_acc
# Out:
#    data_name  num-steps optimizer     lr  num-client-agg  clip  \
# 0     putEMG        264      adam  0.010               5  1.00
# 1     putEMG        264      adam  0.010               5  0.10
# 2     putEMG        264      adam  0.010               5  0.01
# 3     putEMG        264      adam  0.001               5  1.00
# 4     putEMG        264      adam  0.001               5  0.10
# ..       ...        ...       ...    ...             ...   ...
# 57    putEMG        264      adam  0.010               5  0.10
# 58    putEMG        264      adam  0.010               5  0.10
# 59    putEMG        264      adam  0.001               5  0.10
# 60    putEMG        264      adam  0.001               5  0.10
# 61    putEMG        264      adam  0.001               5  0.10
#
#     noise-multiplier  seed  history_size   dp_method  epoch_of_best_val  \
# 0                0.0    42            50  GEP_PUBLIC                 34
# 1                0.0    42            50  GEP_PUBLIC                 34
# 2                0.0    42            50  GEP_PUBLIC                 29
# 3                0.0    42            50  GEP_PUBLIC                 29
# 4                0.0    42            50  GEP_PUBLIC                 29
# ..               ...   ...           ...         ...                ...
# 57              25.0    41           100  GEP_PUBLIC                 34
# 58              25.0    42           100  GEP_PUBLIC                 29
# 59              25.0    40           100  GEP_PUBLIC                 29
# 60              25.0    41           100  GEP_PUBLIC                 29
# 61              25.0    42           100  GEP_PUBLIC                159
#
#     best_val_acc  test_avg_acc
# 0       0.609512      0.607075
# 1       0.609512      0.607075
# 2       0.609512      0.607075
# 3       0.609512      0.607075
# 4       0.609512      0.607075
# ..           ...           ...
# 57      0.609512      0.607075
# 58      0.609512      0.607075
# 59      0.609512      0.607075
# 60      0.609512      0.607075
# 61      0.617684      0.615040
#
# [62 rows x 13 columns]

# %%
good_acc.groupby(['seed'])['test_avg_acc'].std()
# Out:
# seed
# 40    0.002938
# 41    0.129961
# 42    0.249766
# Name: test_avg_acc, dtype: float64
